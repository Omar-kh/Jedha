# %%
import pandas as pd

# %%
import numpy as np

# %%
pd.Series(np.random.randn(10), name='Column name')
# Out:
# 0   -0.308588
# 1   -0.369019
# 2    1.445658
# 3    1.006902
# 4    0.025040
# 5    0.423741
# 6    0.183146
# 7   -0.754403
# 8    0.123572
# 9    0.094716
# Name: Column name, dtype: float64

# %%
pd.DataFrame({"Col_1": np.random.randn(10), "Col_2": np.random.randn(10)})
# Out:
#       Col_1     Col_2
# 0 -0.016272  0.781856
# 1 -0.148978 -0.125204
# 2 -0.169943 -0.975427
# 3  0.384443 -0.116224
# 4  0.055976 -1.155928
# 5  0.006804 -0.251950
# 6 -1.368168  0.322016
# 7  0.417809  0.068416
# 8 -0.402094 -0.764254
# 9  1.023709  0.047028

# %%
#Execute if run in google colab
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-28c8cb46-0040-4cd3-b9fd-265b58af2cbf" name="files[]" multiple disabled />
#      <output id="result-28c8cb46-0040-4cd3-b9fd-265b58af2cbf">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 50_Startups.csv to 50_Startups.csv

# %% [markdown]
# ### Choose the path to your file depending on your work environment

# %%
#Local environment
csv_path = "./Data_for_exercises/50_Startups.csv"

# %%
#Google colab
csv_path = "50_Startups.csv"

# %%
dataset = pd.read_csv(csv_path)
dataset.head()
dataset.tail()
# Out:
#     R&D Spend  Administration  Marketing Spend       State    Profit
# 45    1000.23       124153.04          1903.93    New York  64926.08
# 46    1315.46       115816.21        297114.46     Florida  49490.75
# 47       0.00       135426.92             0.00  California  42559.73
# 48     542.05        51743.15             0.00    New York  35673.41
# 49       0.00       116983.80         45173.06  California  14681.40

# %%
dataset.to_csv("start.csv")

# %%
dataset.index
# Out:
# RangeIndex(start=0, stop=50, step=1)

# %%
dataset.columns
# Out:
# Index(['R&D Spend', 'Administration', 'Marketing Spend', 'State', 'Profit'], dtype='object')

# %%
dataset.loc[:,"Administration"] # is the same as dataset.iloc[:,1]
# Out:
# 0     136897.80
# 1     151377.59
# 2     101145.55
# 3     118671.85
# 4      91391.77
# 5      99814.71
# 6     147198.87
# 7     145530.06
# 8     148718.95
# 9     108679.17
# 10    110594.11
# 11     91790.61
# 12    127320.38
# 13    135495.07
# 14    156547.42
# 15    122616.84
# 16    121597.55
# 17    145077.58
# 18    114175.79
# 19    153514.11
# 20    113867.30
# 21    153773.43
# 22    122782.75
# 23    105751.03
# 24     99281.34
# 25    139553.16
# 26    144135.98
# 27    127864.55
# 28    182645.56
# 29    153032.06
# 30    115641.28
# 31    152701.92
# 32    129219.61
# 33    103057.49
# 34    157693.92
# 35     85047.44
# 36    127056.21
# 37     51283.14
# 38     65947.93
# 39     82982.09
# 40    118546.05
# 41     84710.77
# 42     96189.63
# 43    127382.30
# 44    154806.14
# 45    124153.04
# 46    115816.21
# 47    135426.92
# 48     51743.15
# 49    116983.80
# Name: Administration, dtype: float64

# %%
dataset.loc[4:8, dataset.columns != "Administration"]
# Out:
#    R&D Spend  Marketing Spend       State     Profit
# 4  142107.34        366168.42     Florida  166187.94
# 5  131876.90        362861.36    New York  156991.12
# 6  134615.46        127716.82  California  156122.51
# 7  130298.13        323876.68     Florida  155752.60
# 8  120542.52        311613.29    New York  152211.77

# %%
dataset.mean()
# Out:
# R&D Spend           73721.6156
# Administration     121344.6396
# Marketing Spend    211025.0978
# Profit             112012.6392
# dtype: float64

# %%
dataset.describe()
# Out:
#            R&D Spend  Administration  Marketing Spend         Profit
# count      50.000000       50.000000        50.000000      50.000000
# mean    73721.615600   121344.639600    211025.097800  112012.639200
# std     45902.256482    28017.802755    122290.310726   40306.180338
# min         0.000000    51283.140000         0.000000   14681.400000
# 25%     39936.370000   103730.875000    129300.132500   90138.902500
# 50%     73051.080000   122699.795000    212716.240000  107978.190000
# 75%    101602.800000   144842.180000    299469.085000  139765.977500
# max    165349.200000   182645.560000    471784.100000  192261.830000

# %%
dataset["New Column"] = pd.Series(np.random.randn(len(dataset)))
dataset.head()
# Out:
#    R&D Spend  Administration  ...     Profit New Column
# 0  165349.20       136897.80  ...  192261.83  -0.309722
# 1  162597.70       151377.59  ...  191792.06   0.875992
# 2  153441.51       101145.55  ...  191050.39   0.219673
# 3  144372.41       118671.85  ...  182901.99  -0.685385
# 4  142107.34        91391.77  ...  166187.94  -0.328402
#
# [5 rows x 6 columns]

# %%
dataset.append(pd.Series(np.random.randn(len(dataset.columns))), ignore_index = True)
# Out:
#     R&D Spend  Administration  Marketing Spend  ...         3        4         5
# 0   165349.20       136897.80        471784.10  ...       NaN      NaN       NaN
# 1   162597.70       151377.59        443898.53  ...       NaN      NaN       NaN
# 2   153441.51       101145.55        407934.54  ...       NaN      NaN       NaN
# 3   144372.41       118671.85        383199.62  ...       NaN      NaN       NaN
# 4   142107.34        91391.77        366168.42  ...       NaN      NaN       NaN
# 5   131876.90        99814.71        362861.36  ...       NaN      NaN       NaN
# 6   134615.46       147198.87        127716.82  ...       NaN      NaN       NaN
# 7   130298.13       145530.06        323876.68  ...       NaN      NaN       NaN
# 8   120542.52       148718.95        311613.29  ...       NaN      NaN       NaN
# 9   123334.88       108679.17        304981.62  ...       NaN      NaN       NaN
# 10  101913.08       110594.11        229160.95  ...       NaN      NaN       NaN
# ...

# %%
line_to_append = pd.Series(np.random.randn(len(dataset.columns)), index=dataset.columns)
line_to_append
# Out:
# R&D Spend         -1.471385
# Administration     0.747644
# Marketing Spend    0.192881
# State              0.266454
# Profit             0.044283
# New Column         1.533385
# dtype: float64

# %%
dataset.append(line_to_append, ignore_index = True)
# Out:
#         R&D Spend  Administration  ...         Profit New Column
# 0   165349.200000   136897.800000  ...  192261.830000  -0.309722
# 1   162597.700000   151377.590000  ...  191792.060000   0.875992
# 2   153441.510000   101145.550000  ...  191050.390000   0.219673
# 3   144372.410000   118671.850000  ...  182901.990000  -0.685385
# 4   142107.340000    91391.770000  ...  166187.940000  -0.328402
# 5   131876.900000    99814.710000  ...  156991.120000   0.531916
# 6   134615.460000   147198.870000  ...  156122.510000   0.317904
# 7   130298.130000   145530.060000  ...  155752.600000   0.174661
# 8   120542.520000   148718.950000  ...  152211.770000  -0.207232
# 9   123334.880000   108679.170000  ...  149759.960000  -1.830735
# 10  101913.080000   110594.110000  ...  146121.950000  -0.859194
# 11  100671.960000    91790.610000  ...  144259.400000   1.186189
# 12   93863.750000   127320.380000  ...  141585.520000   0.946513
# ...

# %%
dataset[dataset > dataset.mean()]
# Out:
#     R&D Spend  Administration  Marketing Spend State     Profit  New Column
# 0   165349.20       136897.80        471784.10   NaN  192261.83         NaN
# 1   162597.70       151377.59        443898.53   NaN  191792.06    0.875992
# 2   153441.51             NaN        407934.54   NaN  191050.39    0.219673
# 3   144372.41             NaN        383199.62   NaN  182901.99         NaN
# 4   142107.34             NaN        366168.42   NaN  166187.94         NaN
# 5   131876.90             NaN        362861.36   NaN  156991.12    0.531916
# 6   134615.46       147198.87              NaN   NaN  156122.51    0.317904
# 7   130298.13       145530.06        323876.68   NaN  155752.60    0.174661
# 8   120542.52       148718.95        311613.29   NaN  152211.77         NaN
# 9   123334.88             NaN        304981.62   NaN  149759.96         NaN
# 10  101913.08             NaN        229160.95   NaN  146121.95         NaN
# ...

# %%
dataset[dataset["R&D Spend"] > dataset["R&D Spend"].mean()]
# Out:
#     R&D Spend  Administration  ...     Profit New Column
# 0   165349.20       136897.80  ...  192261.83  -0.309722
# 1   162597.70       151377.59  ...  191792.06   0.875992
# 2   153441.51       101145.55  ...  191050.39   0.219673
# 3   144372.41       118671.85  ...  182901.99  -0.685385
# 4   142107.34        91391.77  ...  166187.94  -0.328402
# 5   131876.90        99814.71  ...  156991.12   0.531916
# 6   134615.46       147198.87  ...  156122.51   0.317904
# 7   130298.13       145530.06  ...  155752.60   0.174661
# 8   120542.52       148718.95  ...  152211.77  -0.207232
# 9   123334.88       108679.17  ...  149759.96  -1.830735
# 10  101913.08       110594.11  ...  146121.95  -0.859194
# 11  100671.96        91790.61  ...  144259.40   1.186189
# 12   93863.75       127320.38  ...  141585.52   0.946513
# 13   91992.39       135495.07  ...  134307.35   0.800793
# 14  119943.24       156547.42  ...  132602.65  -0.910129
# ...

# %%
dataset[np.abs(dataset["Administration"] - dataset["Administration"].mean()) < 2 * dataset["Administration"].std()]
# Out:
#     R&D Spend  Administration  ...     Profit New Column
# 0   165349.20       136897.80  ...  192261.83  -0.309722
# 1   162597.70       151377.59  ...  191792.06   0.875992
# 2   153441.51       101145.55  ...  191050.39   0.219673
# 3   144372.41       118671.85  ...  182901.99  -0.685385
# 4   142107.34        91391.77  ...  166187.94  -0.328402
# 5   131876.90        99814.71  ...  156991.12   0.531916
# 6   134615.46       147198.87  ...  156122.51   0.317904
# 7   130298.13       145530.06  ...  155752.60   0.174661
# 8   120542.52       148718.95  ...  152211.77  -0.207232
# 9   123334.88       108679.17  ...  149759.96  -1.830735
# 10  101913.08       110594.11  ...  146121.95  -0.859194
# 11  100671.96        91790.61  ...  144259.40   1.186189
# 12   93863.75       127320.38  ...  141585.52   0.946513
# 13   91992.39       135495.07  ...  134307.35   0.800793
# 14  119943.24       156547.42  ...  132602.65  -0.910129
# ...

# %%
dataset[(dataset["Administration"] < dataset["Administration"].mean() + 2 * dataset["Administration"].std()) & (dataset["Administration"] > dataset["Administration"].mean() - 2 * dataset["Administration"].std())]
# Out:
#     R&D Spend  Administration  ...     Profit New Column
# 0   165349.20       136897.80  ...  192261.83  -0.309722
# 1   162597.70       151377.59  ...  191792.06   0.875992
# 2   153441.51       101145.55  ...  191050.39   0.219673
# 3   144372.41       118671.85  ...  182901.99  -0.685385
# 4   142107.34        91391.77  ...  166187.94  -0.328402
# 5   131876.90        99814.71  ...  156991.12   0.531916
# 6   134615.46       147198.87  ...  156122.51   0.317904
# 7   130298.13       145530.06  ...  155752.60   0.174661
# 8   120542.52       148718.95  ...  152211.77  -0.207232
# 9   123334.88       108679.17  ...  149759.96  -1.830735
# 10  101913.08       110594.11  ...  146121.95  -0.859194
# 11  100671.96        91790.61  ...  144259.40   1.186189
# 12   93863.75       127320.38  ...  141585.52   0.946513
# 13   91992.39       135495.07  ...  134307.35   0.800793
# 14  119943.24       156547.42  ...  132602.65  -0.910129
# ...

# %%
dataset["New Column"].apply(lambda x: np.abs(x))
# Out:
# 0     0.309722
# 1     0.875992
# 2     0.219673
# 3     0.685385
# 4     0.328402
# 5     0.531916
# 6     0.317904
# 7     0.174661
# 8     0.207232
# 9     1.830735
# 10    0.859194
# 11    1.186189
# 12    0.946513
# 13    0.800793
# 14    0.910129
# 15    0.079356
# 16    0.583196
# 17    1.634420
# 18    0.809170
# 19    0.996041
# 20    0.548436
# 21    0.461783
# 22    0.497513
# 23    0.110707
# 24    1.982234
# 25    1.505767
# 26    0.358816
# 27    0.449290
# 28    0.084293
# 29    1.467701
# 30    0.095337
# 31    0.040968
# 32    0.610383
# 33    0.709021
# 34    1.501112
# 35    0.807122
# 36    0.474065
# 37    0.244484
# 38    0.637665
# 39    1.269298
# 40    0.510236
# 41    0.049671
# 42    0.563158
# 43    1.717759
# 44    1.811549
# 45    0.994175
# 46    1.184529
# 47    0.102641
# 48    1.663788
# 49    0.429836
# Name: New Column, dtype: float64

# %%
#In case of working in google colab
chipo = files.upload()
# Out:
#      <input type="file" id="files-6ff3fd63-e13c-4ad4-b7a8-b33733519c9c" name="files[]" multiple disabled />
#      <output id="result-6ff3fd63-e13c-4ad4-b7a8-b33733519c9c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving chipotle.csv to chipotle.csv

# %% [markdown]
# ### Choose path to the file depending on your environment

# %%
#Google colab
chipotle_path = "chipotle.csv"

# %%
#local
chipotle_path = "./Data_for_exercises/chipotle.csv"

# %%
dataset = pd.read_csv(chipotle_path)
dataset
# Out:
#       Unnamed: 0  order_id  quantity                              item_name  \
# 0              0         1         1           Chips and Fresh Tomato Salsa
# 1              1         1         1                                   Izze
# 2              2         1         1                       Nantucket Nectar
# 3              3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4              4         2         2                           Chicken Bowl
# 5              5         3         1                           Chicken Bowl
# 6              6         3         1                          Side of Chips
# 7              7         4         1                          Steak Burrito
# 8              8         4         1                       Steak Soft Tacos
# 9              9         5         1                          Steak Burrito
# 10            10         5         1                    Chips and Guacamole
# ...

# %%
dataset.head(10)
# Out:
#    Unnamed: 0  ...  item_price
# 0           0  ...      $2.39
# 1           1  ...      $3.39
# 2           2  ...      $3.39
# 3           3  ...      $2.39
# 4           4  ...     $16.98
# 5           5  ...     $10.98
# 6           6  ...      $1.69
# 7           7  ...     $11.75
# 8           8  ...      $9.25
# 9           9  ...      $9.25
#
# [10 rows x 6 columns]

# %%
dataset.shape
# Out:
# (4622, 6)

# %%
dataset.columns
# Out:
# Index(['Unnamed: 0', 'order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %%
grouped_dataset = dataset.groupby("item_name").sum()
#alternative grouped_dataset_with_only_quantity = dataset.groupby("item_name")["quantity"].sum()

# %%
grouped_dataset.sort_values("quantity", ascending = False)
# Out:
#                                        Unnamed: 0  ...  item_price
# item_name                                          ...
# Chicken Bowl                              1779909  ...     7342.73
# Chicken Burrito                           1238217  ...     5575.82
# Chips and Guacamole                       1121773  ...     2201.04
# Steak Burrito                              817795  ...     3851.43
# Canned Soft Drink                          759990  ...      438.75
# Chips                                      518704  ...      494.34
# Steak Bowl                                 482721  ...     2260.19
# Bottled Water                              439354  ...      302.56
# Chips and Fresh Tomato Salsa               250144  ...      361.36
# Canned Soda                                189915  ...      137.34
# Chicken Salad Bowl                         292292  ...     1228.75
# Chicken Soft Tacos                         244891  ...     1108.09
# ...

# %%
np.sum(dataset["quantity"])
# Out:
# 4972

# %%
#dataset["item_price"] = dataset["item_price"].str.replace('$','')
#dataset["item_price"] = dataset["item_price"].apply(lambda x:float(x))
#good alternative dataset["item_price"] = dataset["item_price"].apply(lambda x:float(x[1:]))
tot_item_sale = dataset["item_price"].multiply(dataset["quantity"])
np.sum(tot_item_sale)
# Out:
# 39237.02

# %%
dataset["revenue"] = tot_item_sale
dataset.groupby("order_id").sum().mean()
# Out:
# Unnamed: 0    5822.863141
# quantity         2.711014
# item_price      18.811429
# revenue         21.394231
# dtype: float64
